# %% [markdown]
# 29.11.2020
#
# ### Image Processing in Physics
#
# #### Julia Herzen, Klaus Achterhold, Clemens Schmid, Manuel Schultheiss

# %% [markdown]
# # Exercise 04 -- B: Temperature analysis
#
# In this exercise, we will look at the development of monthly temperature in Germany from 1881 to 2019.
#
# This is a small reference to the [Public Climate School](https://studentsforfuture.info/public-climate-school/).

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.ndimage as nd
import datetime

# %matplotlib notebook

# %% [markdown]
# First, we will load in the data. The temperature per month per federal state ("Bundesland") and German mean are stored in `.csv` files. "csv" stands for "comma-separated values" and denotes a common way to store tabular data.
#
# We have one file per month, each file containing all years. To get all months in all years, we iterate over all files and construct an array from there.
#
# A prevalent and powerful library for loading and processing tabular data is [pandas](https://pandas.pydata.org/). For simplicity, we only use `numpy.loadtxt` here and construct the data ourselves. If you want to handle bigger/more complex datastructures, you should consider using pandas.

# %% [markdown]
# ## Load and analyze

# %% [markdown]
# Define the path to the files with a placeholder for the month. Have a look at the .csv files and how the month is encoded:
# - You need a placeholder for an **integer**: Use `%i` (old style) or `{:d}` (new style)
# - It should be **zero-padded** to length 2: We use `%02i` or `{:02d}` for that.

# %%
fname = "temp/regional_averages_tm_{:02d}.csv"

# %% [markdown]
# Iterate over all files.
# 1. Use the index to complete the filename template from above
# 2. Use the function `np.loadtxt` to load the data as an array. You have to specify the correct delimiter. (Look at the docstring what that means)
# 3. Discard the first two columns, as they only contain the year and the month index.
# 4. Append the remaining data to the list

# %%
np.loadtxt?

# %%
temp_lst = []
for i in range(1,13):
    data = np.loadtxt(fname.format(i), delimiter=";")
    temp_month = data[:,2:]
    temp_lst.append(temp_month)

# %% [markdown]
# Convert the list to an array and check the shape. The axes are (month, year, state). The last "state" is the averaged temperature.

# %%
temp_arr = np.array(temp_lst)
temp_arr.shape

#assert temp_arr.shape == (12, 139, 17)
# Out:
# (12, 139, 17)

# %% [markdown]
# Transpose the data such that states are on the 0-th axis, and combine months and years into one axis. We will use only the mean data for overall Germany, which is the last "state" in our array.

# %%
# Transpose and combine -> (17, 1668)
temp_flat = temp_arr.transpose(2, 1, 0).reshape(17, -1)
print(temp_flat.shape)

# Use only Germany
temp_ger = temp_flat[-1]
# Out:
# (17, 1668)

# %%
temp_flat[-1].shape
# Out:
# (1668,)

# %% [markdown]
# Define the x-axis for plotting all data points. We define the years and the months and combine them to get a long list of `datetime` objects, which pyplot can handle.

# %%
years = np.arange(1881, 2020)
months = np.arange(1, 13)
dates = [datetime.date(year, month, 1)   # `1` is a placeholder for day
         for year in years     # outer loop
         for month in months]  # inner loop
dates
# Out:
# [datetime.date(1881, 1, 1),
#  datetime.date(1881, 2, 1),
#  datetime.date(1881, 3, 1),
#  datetime.date(1881, 4, 1),
#  datetime.date(1881, 5, 1),
#  datetime.date(1881, 6, 1),
#  datetime.date(1881, 7, 1),
#  datetime.date(1881, 8, 1),
#  datetime.date(1881, 9, 1),
#  datetime.date(1881, 10, 1),
#  datetime.date(1881, 11, 1),
#  datetime.date(1881, 12, 1),
#  datetime.date(1882, 1, 1),
#  datetime.date(1882, 2, 1),
#  datetime.date(1882, 3, 1),
#  datetime.date(1882, 4, 1),
#  datetime.date(1882, 5, 1),
#  datetime.date(1882, 6, 1),
#  datetime.date(1882, 7, 1),
#  datetime.date(1882, 8, 1),
#  datetime.date(1882, 9, 1),
#  datetime.date(1882, 10, 1),
#  datetime.date(1882, 11, 1),
#  datetime.date(1882, 12, 1),
#  datetime.date(1883, 1, 1),
#  datetime.date(1883, 2, 1),
#  datetime.date(1883, 3, 1),
#  datetime.date(1883, 4, 1),
#  datetime.date(1883, 5, 1),
#  datetime.date(1883, 6, 1),
#  datetime.date(1883, 7, 1),
#  datetime.date(1883, 8, 1),
#  datetime.date(1883, 9, 1),
#  datetime.date(1883, 10, 1),
#  datetime.date(1883, 11, 1),
#  datetime.date(1883, 12, 1),
#  datetime.date(1884, 1, 1),
#  datetime.date(1884, 2, 1),
#  datetime.date(1884, 3, 1),
#  datetime.date(1884, 4, 1),
#  datetime.date(1884, 5, 1),
#  datetime.date(1884, 6, 1),
#  datetime.date(1884, 7, 1),
#  datetime.date(1884, 8, 1),
#  datetime.date(1884, 9, 1),
#  datetime.date(1884, 10, 1),
#  datetime.date(1884, 11, 1),
#  datetime.date(1884, 12, 1),
#  datetime.date(1885, 1, 1),
#  datetime.date(1885, 2, 1),
#  datetime.date(1885, 3, 1),
#  datetime.date(1885, 4, 1),
#  datetime.date(1885, 5, 1),
#  datetime.date(1885, 6, 1),
#  datetime.date(1885, 7, 1),
#  datetime.date(1885, 8, 1),
#  datetime.date(1885, 9, 1),
#  datetime.date(1885, 10, 1),
#  datetime.date(1885, 11, 1),
#  datetime.date(1885, 12, 1),
#  datetime.date(1886, 1, 1),
#  datetime.date(1886, 2, 1),
#  datetime.date(1886, 3, 1),
#  datetime.date(1886, 4, 1),
#  datetime.date(1886, 5, 1),
#  datetime.date(1886, 6, 1),
#  datetime.date(1886, 7, 1),
#  datetime.date(1886, 8, 1),
#  datetime.date(1886, 9, 1),
#  datetime.date(1886, 10, 1),
#  datetime.date(1886, 11, 1),
#  datetime.date(1886, 12, 1),
#  datetime.date(1887, 1, 1),
#  datetime.date(1887, 2, 1),
#  datetime.date(1887, 3, 1),
#  datetime.date(1887, 4, 1),
#  datetime.date(1887, 5, 1),
#  datetime.date(1887, 6, 1),
#  datetime.date(1887, 7, 1),
#  datetime.date(1887, 8, 1),
#  datetime.date(1887, 9, 1),
#  datetime.date(1887, 10, 1),
#  datetime.date(1887, 11, 1),
#  datetime.date(1887, 12, 1),
#  datetime.date(1888, 1, 1),
#  datetime.date(1888, 2, 1),
#  datetime.date(1888, 3, 1),
#  datetime.date(1888, 4, 1),
#  datetime.date(1888, 5, 1),
#  datetime.date(1888, 6, 1),
#  datetime.date(1888, 7, 1),
#  datetime.date(1888, 8, 1),
#  datetime.date(1888, 9, 1),
#  datetime.date(1888, 10, 1),
#  datetime.date(1888, 11, 1),
#  datetime.date(1888, 12, 1),
#  datetime.date(1889, 1, 1),
#  datetime.date(1889, 2, 1),
#  datetime.date(1889, 3, 1),
#  datetime.date(1889, 4, 1),
#  datetime.date(1889, 5, 1),
#  datetime.date(1889, 6, 1),
#  datetime.date(1889, 7, 1),
#  datetime.date(1889, 8, 1),
#  datetime.date(1889, 9, 1),
#  datetime.date(1889, 10, 1),
#  datetime.date(1889, 11, 1),
#  datetime.date(1889, 12, 1),
#  datetime.date(1890, 1, 1),
#  datetime.date(1890, 2, 1),
#  datetime.date(1890, 3, 1),
#  datetime.date(1890, 4, 1),
#  datetime.date(1890, 5, 1),
#  datetime.date(1890, 6, 1),
#  datetime.date(1890, 7, 1),
#  datetime.date(1890, 8, 1),
#  datetime.date(1890, 9, 1),
#  datetime.date(1890, 10, 1),
#  datetime.date(1890, 11, 1),
#  datetime.date(1890, 12, 1),
#  datetime.date(1891, 1, 1),
#  datetime.date(1891, 2, 1),
#  datetime.date(1891, 3, 1),
#  datetime.date(1891, 4, 1),
#  datetime.date(1891, 5, 1),
#  datetime.date(1891, 6, 1),
#  datetime.date(1891, 7, 1),
#  datetime.date(1891, 8, 1),
#  datetime.date(1891, 9, 1),
#  datetime.date(1891, 10, 1),
#  datetime.date(1891, 11, 1),
#  datetime.date(1891, 12, 1),
#  datetime.date(1892, 1, 1),
#  datetime.date(1892, 2, 1),
#  datetime.date(1892, 3, 1),
#  datetime.date(1892, 4, 1),
#  datetime.date(1892, 5, 1),
#  datetime.date(1892, 6, 1),
#  datetime.date(1892, 7, 1),
#  datetime.date(1892, 8, 1),
#  datetime.date(1892, 9, 1),
#  datetime.date(1892, 10, 1),
#  datetime.date(1892, 11, 1),
#  datetime.date(1892, 12, 1),
#  datetime.date(1893, 1, 1),
#  datetime.date(1893, 2, 1),
#  datetime.date(1893, 3, 1),
#  datetime.date(1893, 4, 1),
#  datetime.date(1893, 5, 1),
#  datetime.date(1893, 6, 1),
#  datetime.date(1893, 7, 1),
#  datetime.date(1893, 8, 1),
#  datetime.date(1893, 9, 1),
#  datetime.date(1893, 10, 1),
#  datetime.date(1893, 11, 1),
#  datetime.date(1893, 12, 1),
#  datetime.date(1894, 1, 1),
#  datetime.date(1894, 2, 1),
#  datetime.date(1894, 3, 1),
#  datetime.date(1894, 4, 1),
#  datetime.date(1894, 5, 1),
#  datetime.date(1894, 6, 1),
#  datetime.date(1894, 7, 1),
#  datetime.date(1894, 8, 1),
#  datetime.date(1894, 9, 1),
#  datetime.date(1894, 10, 1),
#  datetime.date(1894, 11, 1),
#  datetime.date(1894, 12, 1),
#  datetime.date(1895, 1, 1),
#  datetime.date(1895, 2, 1),
#  datetime.date(1895, 3, 1),
#  datetime.date(1895, 4, 1),
#  datetime.date(1895, 5, 1),
#  datetime.date(1895, 6, 1),
#  datetime.date(1895, 7, 1),
#  datetime.date(1895, 8, 1),
#  datetime.date(1895, 9, 1),
#  datetime.date(1895, 10, 1),
#  datetime.date(1895, 11, 1),
#  datetime.date(1895, 12, 1),
#  datetime.date(1896, 1, 1),
#  datetime.date(1896, 2, 1),
#  datetime.date(1896, 3, 1),
#  datetime.date(1896, 4, 1),
#  datetime.date(1896, 5, 1),
#  datetime.date(1896, 6, 1),
#  datetime.date(1896, 7, 1),
#  datetime.date(1896, 8, 1),
#  datetime.date(1896, 9, 1),
#  datetime.date(1896, 10, 1),
#  datetime.date(1896, 11, 1),
#  datetime.date(1896, 12, 1),
#  datetime.date(1897, 1, 1),
#  datetime.date(1897, 2, 1),
#  datetime.date(1897, 3, 1),
#  datetime.date(1897, 4, 1),
#  datetime.date(1897, 5, 1),
#  datetime.date(1897, 6, 1),
#  datetime.date(1897, 7, 1),
#  datetime.date(1897, 8, 1),
#  datetime.date(1897, 9, 1),
#  datetime.date(1897, 10, 1),
#  datetime.date(1897, 11, 1),
#  datetime.date(1897, 12, 1),
#  datetime.date(1898, 1, 1),
#  datetime.date(1898, 2, 1),
#  datetime.date(1898, 3, 1),
#  datetime.date(1898, 4, 1),
#  datetime.date(1898, 5, 1),
#  datetime.date(1898, 6, 1),
#  datetime.date(1898, 7, 1),
#  datetime.date(1898, 8, 1),
#  datetime.date(1898, 9, 1),
#  datetime.date(1898, 10, 1),
#  datetime.date(1898, 11, 1),
#  datetime.date(1898, 12, 1),
#  datetime.date(1899, 1, 1),
#  datetime.date(1899, 2, 1),
#  datetime.date(1899, 3, 1),
#  datetime.date(1899, 4, 1),
#  datetime.date(1899, 5, 1),
#  datetime.date(1899, 6, 1),
#  datetime.date(1899, 7, 1),
#  datetime.date(1899, 8, 1),
#  datetime.date(1899, 9, 1),
#  datetime.date(1899, 10, 1),
#  datetime.date(1899, 11, 1),
#  datetime.date(1899, 12, 1),
#  datetime.date(1900, 1, 1),
#  datetime.date(1900, 2, 1),
#  datetime.date(1900, 3, 1),
#  datetime.date(1900, 4, 1),
#  datetime.date(1900, 5, 1),
#  datetime.date(1900, 6, 1),
#  datetime.date(1900, 7, 1),
#  datetime.date(1900, 8, 1),
#  datetime.date(1900, 9, 1),
#  datetime.date(1900, 10, 1),
#  datetime.date(1900, 11, 1),
#  datetime.date(1900, 12, 1),
#  datetime.date(1901, 1, 1),
#  datetime.date(1901, 2, 1),
#  datetime.date(1901, 3, 1),
#  datetime.date(1901, 4, 1),
#  datetime.date(1901, 5, 1),
#  datetime.date(1901, 6, 1),
#  datetime.date(1901, 7, 1),
#  datetime.date(1901, 8, 1),
#  datetime.date(1901, 9, 1),
#  datetime.date(1901, 10, 1),
#  datetime.date(1901, 11, 1),
#  datetime.date(1901, 12, 1),
#  datetime.date(1902, 1, 1),
#  datetime.date(1902, 2, 1),
#  datetime.date(1902, 3, 1),
#  datetime.date(1902, 4, 1),
#  datetime.date(1902, 5, 1),
#  datetime.date(1902, 6, 1),
#  datetime.date(1902, 7, 1),
#  datetime.date(1902, 8, 1),
#  datetime.date(1902, 9, 1),
#  datetime.date(1902, 10, 1),
#  datetime.date(1902, 11, 1),
#  datetime.date(1902, 12, 1),
#  datetime.date(1903, 1, 1),
#  datetime.date(1903, 2, 1),
#  datetime.date(1903, 3, 1),
#  datetime.date(1903, 4, 1),
#  datetime.date(1903, 5, 1),
#  datetime.date(1903, 6, 1),
#  datetime.date(1903, 7, 1),
#  datetime.date(1903, 8, 1),
#  datetime.date(1903, 9, 1),
#  datetime.date(1903, 10, 1),
#  datetime.date(1903, 11, 1),
#  datetime.date(1903, 12, 1),
#  datetime.date(1904, 1, 1),
#  datetime.date(1904, 2, 1),
#  datetime.date(1904, 3, 1),
#  datetime.date(1904, 4, 1),
#  datetime.date(1904, 5, 1),
#  datetime.date(1904, 6, 1),
#  datetime.date(1904, 7, 1),
#  datetime.date(1904, 8, 1),
#  datetime.date(1904, 9, 1),
#  datetime.date(1904, 10, 1),
#  datetime.date(1904, 11, 1),
#  datetime.date(1904, 12, 1),
#  datetime.date(1905, 1, 1),
#  datetime.date(1905, 2, 1),
#  datetime.date(1905, 3, 1),
#  datetime.date(1905, 4, 1),
#  datetime.date(1905, 5, 1),
#  datetime.date(1905, 6, 1),
#  datetime.date(1905, 7, 1),
#  datetime.date(1905, 8, 1),
#  datetime.date(1905, 9, 1),
#  datetime.date(1905, 10, 1),
#  datetime.date(1905, 11, 1),
#  datetime.date(1905, 12, 1),
#  datetime.date(1906, 1, 1),
#  datetime.date(1906, 2, 1),
#  datetime.date(1906, 3, 1),
#  datetime.date(1906, 4, 1),
#  datetime.date(1906, 5, 1),
#  datetime.date(1906, 6, 1),
#  datetime.date(1906, 7, 1),
#  datetime.date(1906, 8, 1),
#  datetime.date(1906, 9, 1),
#  datetime.date(1906, 10, 1),
#  datetime.date(1906, 11, 1),
#  datetime.date(1906, 12, 1),
#  datetime.date(1907, 1, 1),
#  datetime.date(1907, 2, 1),
#  datetime.date(1907, 3, 1),
#  datetime.date(1907, 4, 1),
#  datetime.date(1907, 5, 1),
#  datetime.date(1907, 6, 1),
#  datetime.date(1907, 7, 1),
#  datetime.date(1907, 8, 1),
#  datetime.date(1907, 9, 1),
#  datetime.date(1907, 10, 1),
#  datetime.date(1907, 11, 1),
#  datetime.date(1907, 12, 1),
#  datetime.date(1908, 1, 1),
#  datetime.date(1908, 2, 1),
#  datetime.date(1908, 3, 1),
#  datetime.date(1908, 4, 1),
#  datetime.date(1908, 5, 1),
#  datetime.date(1908, 6, 1),
#  datetime.date(1908, 7, 1),
#  datetime.date(1908, 8, 1),
#  datetime.date(1908, 9, 1),
#  datetime.date(1908, 10, 1),
#  datetime.date(1908, 11, 1),
#  datetime.date(1908, 12, 1),
#  datetime.date(1909, 1, 1),
#  datetime.date(1909, 2, 1),
#  datetime.date(1909, 3, 1),
#  datetime.date(1909, 4, 1),
#  datetime.date(1909, 5, 1),
#  datetime.date(1909, 6, 1),
#  datetime.date(1909, 7, 1),
#  datetime.date(1909, 8, 1),
#  datetime.date(1909, 9, 1),
#  datetime.date(1909, 10, 1),
#  datetime.date(1909, 11, 1),
#  datetime.date(1909, 12, 1),
#  datetime.date(1910, 1, 1),
#  datetime.date(1910, 2, 1),
#  datetime.date(1910, 3, 1),
#  datetime.date(1910, 4, 1),
#  datetime.date(1910, 5, 1),
#  datetime.date(1910, 6, 1),
#  datetime.date(1910, 7, 1),
#  datetime.date(1910, 8, 1),
#  datetime.date(1910, 9, 1),
#  datetime.date(1910, 10, 1),
#  datetime.date(1910, 11, 1),
#  datetime.date(1910, 12, 1),
#  datetime.date(1911, 1, 1),
#  datetime.date(1911, 2, 1),
#  datetime.date(1911, 3, 1),
#  datetime.date(1911, 4, 1),
#  datetime.date(1911, 5, 1),
#  datetime.date(1911, 6, 1),
#  datetime.date(1911, 7, 1),
#  datetime.date(1911, 8, 1),
#  datetime.date(1911, 9, 1),
#  datetime.date(1911, 10, 1),
#  datetime.date(1911, 11, 1),
#  datetime.date(1911, 12, 1),
#  datetime.date(1912, 1, 1),
#  datetime.date(1912, 2, 1),
#  datetime.date(1912, 3, 1),
#  datetime.date(1912, 4, 1),
#  datetime.date(1912, 5, 1),
#  datetime.date(1912, 6, 1),
#  datetime.date(1912, 7, 1),
#  datetime.date(1912, 8, 1),
#  datetime.date(1912, 9, 1),
#  datetime.date(1912, 10, 1),
#  datetime.date(1912, 11, 1),
#  datetime.date(1912, 12, 1),
#  datetime.date(1913, 1, 1),
#  datetime.date(1913, 2, 1),
#  datetime.date(1913, 3, 1),
#  datetime.date(1913, 4, 1),
#  datetime.date(1913, 5, 1),
#  datetime.date(1913, 6, 1),
#  datetime.date(1913, 7, 1),
#  datetime.date(1913, 8, 1),
#  datetime.date(1913, 9, 1),
#  datetime.date(1913, 10, 1),
#  datetime.date(1913, 11, 1),
#  datetime.date(1913, 12, 1),
#  datetime.date(1914, 1, 1),
#  datetime.date(1914, 2, 1),
#  datetime.date(1914, 3, 1),
#  datetime.date(1914, 4, 1),
#  datetime.date(1914, 5, 1),
#  datetime.date(1914, 6, 1),
#  datetime.date(1914, 7, 1),
#  datetime.date(1914, 8, 1),
#  datetime.date(1914, 9, 1),
#  datetime.date(1914, 10, 1),
#  datetime.date(1914, 11, 1),
#  datetime.date(1914, 12, 1),
#  datetime.date(1915, 1, 1),
#  datetime.date(1915, 2, 1),
#  datetime.date(1915, 3, 1),
#  datetime.date(1915, 4, 1),
#  datetime.date(1915, 5, 1),
#  datetime.date(1915, 6, 1),
#  datetime.date(1915, 7, 1),
#  datetime.date(1915, 8, 1),
#  datetime.date(1915, 9, 1),
#  datetime.date(1915, 10, 1),
#  datetime.date(1915, 11, 1),
#  datetime.date(1915, 12, 1),
#  datetime.date(1916, 1, 1),
#  datetime.date(1916, 2, 1),
#  datetime.date(1916, 3, 1),
#  datetime.date(1916, 4, 1),
#  datetime.date(1916, 5, 1),
#  datetime.date(1916, 6, 1),
#  datetime.date(1916, 7, 1),
#  datetime.date(1916, 8, 1),
#  datetime.date(1916, 9, 1),
#  datetime.date(1916, 10, 1),
#  datetime.date(1916, 11, 1),
#  datetime.date(1916, 12, 1),
#  datetime.date(1917, 1, 1),
#  datetime.date(1917, 2, 1),
#  datetime.date(1917, 3, 1),
#  datetime.date(1917, 4, 1),
#  datetime.date(1917, 5, 1),
#  datetime.date(1917, 6, 1),
#  datetime.date(1917, 7, 1),
#  datetime.date(1917, 8, 1),
#  datetime.date(1917, 9, 1),
#  datetime.date(1917, 10, 1),
#  datetime.date(1917, 11, 1),
#  datetime.date(1917, 12, 1),
#  datetime.date(1918, 1, 1),
#  datetime.date(1918, 2, 1),
#  datetime.date(1918, 3, 1),
#  datetime.date(1918, 4, 1),
#  datetime.date(1918, 5, 1),
#  datetime.date(1918, 6, 1),
#  datetime.date(1918, 7, 1),
#  datetime.date(1918, 8, 1),
#  datetime.date(1918, 9, 1),
#  datetime.date(1918, 10, 1),
#  datetime.date(1918, 11, 1),
#  datetime.date(1918, 12, 1),
#  datetime.date(1919, 1, 1),
#  datetime.date(1919, 2, 1),
#  datetime.date(1919, 3, 1),
#  datetime.date(1919, 4, 1),
#  datetime.date(1919, 5, 1),
#  datetime.date(1919, 6, 1),
#  datetime.date(1919, 7, 1),
#  datetime.date(1919, 8, 1),
#  datetime.date(1919, 9, 1),
#  datetime.date(1919, 10, 1),
#  datetime.date(1919, 11, 1),
#  datetime.date(1919, 12, 1),
#  datetime.date(1920, 1, 1),
#  datetime.date(1920, 2, 1),
#  datetime.date(1920, 3, 1),
#  datetime.date(1920, 4, 1),
#  datetime.date(1920, 5, 1),
#  datetime.date(1920, 6, 1),
#  datetime.date(1920, 7, 1),
#  datetime.date(1920, 8, 1),
#  datetime.date(1920, 9, 1),
#  datetime.date(1920, 10, 1),
#  datetime.date(1920, 11, 1),
#  datetime.date(1920, 12, 1),
#  datetime.date(1921, 1, 1),
#  datetime.date(1921, 2, 1),
#  datetime.date(1921, 3, 1),
#  datetime.date(1921, 4, 1),
#  datetime.date(1921, 5, 1),
#  datetime.date(1921, 6, 1),
#  datetime.date(1921, 7, 1),
#  datetime.date(1921, 8, 1),
#  datetime.date(1921, 9, 1),
#  datetime.date(1921, 10, 1),
#  datetime.date(1921, 11, 1),
#  datetime.date(1921, 12, 1),
#  datetime.date(1922, 1, 1),
#  datetime.date(1922, 2, 1),
#  datetime.date(1922, 3, 1),
#  datetime.date(1922, 4, 1),
#  datetime.date(1922, 5, 1),
#  datetime.date(1922, 6, 1),
#  datetime.date(1922, 7, 1),
#  datetime.date(1922, 8, 1),
#  datetime.date(1922, 9, 1),
#  datetime.date(1922, 10, 1),
#  datetime.date(1922, 11, 1),
#  datetime.date(1922, 12, 1),
#  datetime.date(1923, 1, 1),
#  datetime.date(1923, 2, 1),
#  datetime.date(1923, 3, 1),
#  datetime.date(1923, 4, 1),
#  datetime.date(1923, 5, 1),
#  datetime.date(1923, 6, 1),
#  datetime.date(1923, 7, 1),
#  datetime.date(1923, 8, 1),
#  datetime.date(1923, 9, 1),
#  datetime.date(1923, 10, 1),
#  datetime.date(1923, 11, 1),
#  datetime.date(1923, 12, 1),
#  datetime.date(1924, 1, 1),
#  datetime.date(1924, 2, 1),
#  datetime.date(1924, 3, 1),
#  datetime.date(1924, 4, 1),
#  datetime.date(1924, 5, 1),
#  datetime.date(1924, 6, 1),
#  datetime.date(1924, 7, 1),
#  datetime.date(1924, 8, 1),
#  datetime.date(1924, 9, 1),
#  datetime.date(1924, 10, 1),
#  datetime.date(1924, 11, 1),
#  datetime.date(1924, 12, 1),
#  datetime.date(1925, 1, 1),
#  datetime.date(1925, 2, 1),
#  datetime.date(1925, 3, 1),
#  datetime.date(1925, 4, 1),
#  datetime.date(1925, 5, 1),
#  datetime.date(1925, 6, 1),
#  datetime.date(1925, 7, 1),
#  datetime.date(1925, 8, 1),
#  datetime.date(1925, 9, 1),
#  datetime.date(1925, 10, 1),
#  datetime.date(1925, 11, 1),
#  datetime.date(1925, 12, 1),
#  datetime.date(1926, 1, 1),
#  datetime.date(1926, 2, 1),
#  datetime.date(1926, 3, 1),
#  datetime.date(1926, 4, 1),
#  datetime.date(1926, 5, 1),
#  datetime.date(1926, 6, 1),
#  datetime.date(1926, 7, 1),
#  datetime.date(1926, 8, 1),
#  datetime.date(1926, 9, 1),
#  datetime.date(1926, 10, 1),
#  datetime.date(1926, 11, 1),
#  datetime.date(1926, 12, 1),
#  datetime.date(1927, 1, 1),
#  datetime.date(1927, 2, 1),
#  datetime.date(1927, 3, 1),
#  datetime.date(1927, 4, 1),
#  datetime.date(1927, 5, 1),
#  datetime.date(1927, 6, 1),
#  datetime.date(1927, 7, 1),
#  datetime.date(1927, 8, 1),
#  datetime.date(1927, 9, 1),
#  datetime.date(1927, 10, 1),
#  datetime.date(1927, 11, 1),
#  datetime.date(1927, 12, 1),
#  datetime.date(1928, 1, 1),
#  datetime.date(1928, 2, 1),
#  datetime.date(1928, 3, 1),
#  datetime.date(1928, 4, 1),
#  datetime.date(1928, 5, 1),
#  datetime.date(1928, 6, 1),
#  datetime.date(1928, 7, 1),
#  datetime.date(1928, 8, 1),
#  datetime.date(1928, 9, 1),
#  datetime.date(1928, 10, 1),
#  datetime.date(1928, 11, 1),
#  datetime.date(1928, 12, 1),
#  datetime.date(1929, 1, 1),
#  datetime.date(1929, 2, 1),
#  datetime.date(1929, 3, 1),
#  datetime.date(1929, 4, 1),
#  datetime.date(1929, 5, 1),
#  datetime.date(1929, 6, 1),
#  datetime.date(1929, 7, 1),
#  datetime.date(1929, 8, 1),
#  datetime.date(1929, 9, 1),
#  datetime.date(1929, 10, 1),
#  datetime.date(1929, 11, 1),
#  datetime.date(1929, 12, 1),
#  datetime.date(1930, 1, 1),
#  datetime.date(1930, 2, 1),
#  datetime.date(1930, 3, 1),
#  datetime.date(1930, 4, 1),
#  datetime.date(1930, 5, 1),
#  datetime.date(1930, 6, 1),
#  datetime.date(1930, 7, 1),
#  datetime.date(1930, 8, 1),
#  datetime.date(1930, 9, 1),
#  datetime.date(1930, 10, 1),
#  datetime.date(1930, 11, 1),
#  datetime.date(1930, 12, 1),
#  datetime.date(1931, 1, 1),
#  datetime.date(1931, 2, 1),
#  datetime.date(1931, 3, 1),
#  datetime.date(1931, 4, 1),
#  datetime.date(1931, 5, 1),
#  datetime.date(1931, 6, 1),
#  datetime.date(1931, 7, 1),
#  datetime.date(1931, 8, 1),
#  datetime.date(1931, 9, 1),
#  datetime.date(1931, 10, 1),
#  datetime.date(1931, 11, 1),
#  datetime.date(1931, 12, 1),
#  datetime.date(1932, 1, 1),
#  datetime.date(1932, 2, 1),
#  datetime.date(1932, 3, 1),
#  datetime.date(1932, 4, 1),
#  datetime.date(1932, 5, 1),
#  datetime.date(1932, 6, 1),
#  datetime.date(1932, 7, 1),
#  datetime.date(1932, 8, 1),
#  datetime.date(1932, 9, 1),
#  datetime.date(1932, 10, 1),
#  datetime.date(1932, 11, 1),
#  datetime.date(1932, 12, 1),
#  datetime.date(1933, 1, 1),
#  datetime.date(1933, 2, 1),
#  datetime.date(1933, 3, 1),
#  datetime.date(1933, 4, 1),
#  datetime.date(1933, 5, 1),
#  datetime.date(1933, 6, 1),
#  datetime.date(1933, 7, 1),
#  datetime.date(1933, 8, 1),
#  datetime.date(1933, 9, 1),
#  datetime.date(1933, 10, 1),
#  datetime.date(1933, 11, 1),
#  datetime.date(1933, 12, 1),
#  datetime.date(1934, 1, 1),
#  datetime.date(1934, 2, 1),
#  datetime.date(1934, 3, 1),
#  datetime.date(1934, 4, 1),
#  datetime.date(1934, 5, 1),
#  datetime.date(1934, 6, 1),
#  datetime.date(1934, 7, 1),
#  datetime.date(1934, 8, 1),
#  datetime.date(1934, 9, 1),
#  datetime.date(1934, 10, 1),
#  datetime.date(1934, 11, 1),
#  datetime.date(1934, 12, 1),
#  datetime.date(1935, 1, 1),
#  datetime.date(1935, 2, 1),
#  datetime.date(1935, 3, 1),
#  datetime.date(1935, 4, 1),
#  datetime.date(1935, 5, 1),
#  datetime.date(1935, 6, 1),
#  datetime.date(1935, 7, 1),
#  datetime.date(1935, 8, 1),
#  datetime.date(1935, 9, 1),
#  datetime.date(1935, 10, 1),
#  datetime.date(1935, 11, 1),
#  datetime.date(1935, 12, 1),
#  datetime.date(1936, 1, 1),
#  datetime.date(1936, 2, 1),
#  datetime.date(1936, 3, 1),
#  datetime.date(1936, 4, 1),
#  datetime.date(1936, 5, 1),
#  datetime.date(1936, 6, 1),
#  datetime.date(1936, 7, 1),
#  datetime.date(1936, 8, 1),
#  datetime.date(1936, 9, 1),
#  datetime.date(1936, 10, 1),
#  datetime.date(1936, 11, 1),
#  datetime.date(1936, 12, 1),
#  datetime.date(1937, 1, 1),
#  datetime.date(1937, 2, 1),
#  datetime.date(1937, 3, 1),
#  datetime.date(1937, 4, 1),
#  datetime.date(1937, 5, 1),
#  datetime.date(1937, 6, 1),
#  datetime.date(1937, 7, 1),
#  datetime.date(1937, 8, 1),
#  datetime.date(1937, 9, 1),
#  datetime.date(1937, 10, 1),
#  datetime.date(1937, 11, 1),
#  datetime.date(1937, 12, 1),
#  datetime.date(1938, 1, 1),
#  datetime.date(1938, 2, 1),
#  datetime.date(1938, 3, 1),
#  datetime.date(1938, 4, 1),
#  datetime.date(1938, 5, 1),
#  datetime.date(1938, 6, 1),
#  datetime.date(1938, 7, 1),
#  datetime.date(1938, 8, 1),
#  datetime.date(1938, 9, 1),
#  datetime.date(1938, 10, 1),
#  datetime.date(1938, 11, 1),
#  datetime.date(1938, 12, 1),
#  datetime.date(1939, 1, 1),
#  datetime.date(1939, 2, 1),
#  datetime.date(1939, 3, 1),
#  datetime.date(1939, 4, 1),
#  datetime.date(1939, 5, 1),
#  datetime.date(1939, 6, 1),
#  datetime.date(1939, 7, 1),
#  datetime.date(1939, 8, 1),
#  datetime.date(1939, 9, 1),
#  datetime.date(1939, 10, 1),
#  datetime.date(1939, 11, 1),
#  datetime.date(1939, 12, 1),
#  datetime.date(1940, 1, 1),
#  datetime.date(1940, 2, 1),
#  datetime.date(1940, 3, 1),
#  datetime.date(1940, 4, 1),
#  datetime.date(1940, 5, 1),
#  datetime.date(1940, 6, 1),
#  datetime.date(1940, 7, 1),
#  datetime.date(1940, 8, 1),
#  datetime.date(1940, 9, 1),
#  datetime.date(1940, 10, 1),
#  datetime.date(1940, 11, 1),
#  datetime.date(1940, 12, 1),
#  datetime.date(1941, 1, 1),
#  datetime.date(1941, 2, 1),
#  datetime.date(1941, 3, 1),
#  datetime.date(1941, 4, 1),
#  datetime.date(1941, 5, 1),
#  datetime.date(1941, 6, 1),
#  datetime.date(1941, 7, 1),
#  datetime.date(1941, 8, 1),
#  datetime.date(1941, 9, 1),
#  datetime.date(1941, 10, 1),
#  datetime.date(1941, 11, 1),
#  datetime.date(1941, 12, 1),
#  datetime.date(1942, 1, 1),
#  datetime.date(1942, 2, 1),
#  datetime.date(1942, 3, 1),
#  datetime.date(1942, 4, 1),
#  datetime.date(1942, 5, 1),
#  datetime.date(1942, 6, 1),
#  datetime.date(1942, 7, 1),
#  datetime.date(1942, 8, 1),
#  datetime.date(1942, 9, 1),
#  datetime.date(1942, 10, 1),
#  datetime.date(1942, 11, 1),
#  datetime.date(1942, 12, 1),
#  datetime.date(1943, 1, 1),
#  datetime.date(1943, 2, 1),
#  datetime.date(1943, 3, 1),
#  datetime.date(1943, 4, 1),
#  datetime.date(1943, 5, 1),
#  datetime.date(1943, 6, 1),
#  datetime.date(1943, 7, 1),
#  datetime.date(1943, 8, 1),
#  datetime.date(1943, 9, 1),
#  datetime.date(1943, 10, 1),
#  datetime.date(1943, 11, 1),
#  datetime.date(1943, 12, 1),
#  datetime.date(1944, 1, 1),
#  datetime.date(1944, 2, 1),
#  datetime.date(1944, 3, 1),
#  datetime.date(1944, 4, 1),
#  datetime.date(1944, 5, 1),
#  datetime.date(1944, 6, 1),
#  datetime.date(1944, 7, 1),
#  datetime.date(1944, 8, 1),
#  datetime.date(1944, 9, 1),
#  datetime.date(1944, 10, 1),
#  datetime.date(1944, 11, 1),
#  datetime.date(1944, 12, 1),
#  datetime.date(1945, 1, 1),
#  datetime.date(1945, 2, 1),
#  datetime.date(1945, 3, 1),
#  datetime.date(1945, 4, 1),
#  datetime.date(1945, 5, 1),
#  datetime.date(1945, 6, 1),
#  datetime.date(1945, 7, 1),
#  datetime.date(1945, 8, 1),
#  datetime.date(1945, 9, 1),
#  datetime.date(1945, 10, 1),
#  datetime.date(1945, 11, 1),
#  datetime.date(1945, 12, 1),
#  datetime.date(1946, 1, 1),
#  datetime.date(1946, 2, 1),
#  datetime.date(1946, 3, 1),
#  datetime.date(1946, 4, 1),
#  datetime.date(1946, 5, 1),
#  datetime.date(1946, 6, 1),
#  datetime.date(1946, 7, 1),
#  datetime.date(1946, 8, 1),
#  datetime.date(1946, 9, 1),
#  datetime.date(1946, 10, 1),
#  datetime.date(1946, 11, 1),
#  datetime.date(1946, 12, 1),
#  datetime.date(1947, 1, 1),
#  datetime.date(1947, 2, 1),
#  datetime.date(1947, 3, 1),
#  datetime.date(1947, 4, 1),
#  datetime.date(1947, 5, 1),
#  datetime.date(1947, 6, 1),
#  datetime.date(1947, 7, 1),
#  datetime.date(1947, 8, 1),
#  datetime.date(1947, 9, 1),
#  datetime.date(1947, 10, 1),
#  datetime.date(1947, 11, 1),
#  datetime.date(1947, 12, 1),
#  datetime.date(1948, 1, 1),
#  datetime.date(1948, 2, 1),
#  datetime.date(1948, 3, 1),
#  datetime.date(1948, 4, 1),
#  datetime.date(1948, 5, 1),
#  datetime.date(1948, 6, 1),
#  datetime.date(1948, 7, 1),
#  datetime.date(1948, 8, 1),
#  datetime.date(1948, 9, 1),
#  datetime.date(1948, 10, 1),
#  datetime.date(1948, 11, 1),
#  datetime.date(1948, 12, 1),
#  datetime.date(1949, 1, 1),
#  datetime.date(1949, 2, 1),
#  datetime.date(1949, 3, 1),
#  datetime.date(1949, 4, 1),
#  datetime.date(1949, 5, 1),
#  datetime.date(1949, 6, 1),
#  datetime.date(1949, 7, 1),
#  datetime.date(1949, 8, 1),
#  datetime.date(1949, 9, 1),
#  datetime.date(1949, 10, 1),
#  datetime.date(1949, 11, 1),
#  datetime.date(1949, 12, 1),
#  datetime.date(1950, 1, 1),
#  datetime.date(1950, 2, 1),
#  datetime.date(1950, 3, 1),
#  datetime.date(1950, 4, 1),
#  datetime.date(1950, 5, 1),
#  datetime.date(1950, 6, 1),
#  datetime.date(1950, 7, 1),
#  datetime.date(1950, 8, 1),
#  datetime.date(1950, 9, 1),
#  datetime.date(1950, 10, 1),
#  datetime.date(1950, 11, 1),
#  datetime.date(1950, 12, 1),
#  datetime.date(1951, 1, 1),
#  datetime.date(1951, 2, 1),
#  datetime.date(1951, 3, 1),
#  datetime.date(1951, 4, 1),
#  datetime.date(1951, 5, 1),
#  datetime.date(1951, 6, 1),
#  datetime.date(1951, 7, 1),
#  datetime.date(1951, 8, 1),
#  datetime.date(1951, 9, 1),
#  datetime.date(1951, 10, 1),
#  datetime.date(1951, 11, 1),
#  datetime.date(1951, 12, 1),
#  datetime.date(1952, 1, 1),
#  datetime.date(1952, 2, 1),
#  datetime.date(1952, 3, 1),
#  datetime.date(1952, 4, 1),
#  datetime.date(1952, 5, 1),
#  datetime.date(1952, 6, 1),
#  datetime.date(1952, 7, 1),
#  datetime.date(1952, 8, 1),
#  datetime.date(1952, 9, 1),
#  datetime.date(1952, 10, 1),
#  datetime.date(1952, 11, 1),
#  datetime.date(1952, 12, 1),
#  datetime.date(1953, 1, 1),
#  datetime.date(1953, 2, 1),
#  datetime.date(1953, 3, 1),
#  datetime.date(1953, 4, 1),
#  datetime.date(1953, 5, 1),
#  datetime.date(1953, 6, 1),
#  datetime.date(1953, 7, 1),
#  datetime.date(1953, 8, 1),
#  datetime.date(1953, 9, 1),
#  datetime.date(1953, 10, 1),
#  datetime.date(1953, 11, 1),
#  datetime.date(1953, 12, 1),
#  datetime.date(1954, 1, 1),
#  datetime.date(1954, 2, 1),
#  datetime.date(1954, 3, 1),
#  datetime.date(1954, 4, 1),
#  datetime.date(1954, 5, 1),
#  datetime.date(1954, 6, 1),
#  datetime.date(1954, 7, 1),
#  datetime.date(1954, 8, 1),
#  datetime.date(1954, 9, 1),
#  datetime.date(1954, 10, 1),
#  datetime.date(1954, 11, 1),
#  datetime.date(1954, 12, 1),
#  datetime.date(1955, 1, 1),
#  datetime.date(1955, 2, 1),
#  datetime.date(1955, 3, 1),
#  datetime.date(1955, 4, 1),
#  datetime.date(1955, 5, 1),
#  datetime.date(1955, 6, 1),
#  datetime.date(1955, 7, 1),
#  datetime.date(1955, 8, 1),
#  datetime.date(1955, 9, 1),
#  datetime.date(1955, 10, 1),
#  datetime.date(1955, 11, 1),
#  datetime.date(1955, 12, 1),
#  datetime.date(1956, 1, 1),
#  datetime.date(1956, 2, 1),
#  datetime.date(1956, 3, 1),
#  datetime.date(1956, 4, 1),
#  datetime.date(1956, 5, 1),
#  datetime.date(1956, 6, 1),
#  datetime.date(1956, 7, 1),
#  datetime.date(1956, 8, 1),
#  datetime.date(1956, 9, 1),
#  datetime.date(1956, 10, 1),
#  datetime.date(1956, 11, 1),
#  datetime.date(1956, 12, 1),
#  datetime.date(1957, 1, 1),
#  datetime.date(1957, 2, 1),
#  datetime.date(1957, 3, 1),
#  datetime.date(1957, 4, 1),
#  datetime.date(1957, 5, 1),
#  datetime.date(1957, 6, 1),
#  datetime.date(1957, 7, 1),
#  datetime.date(1957, 8, 1),
#  datetime.date(1957, 9, 1),
#  datetime.date(1957, 10, 1),
#  datetime.date(1957, 11, 1),
#  datetime.date(1957, 12, 1),
#  datetime.date(1958, 1, 1),
#  datetime.date(1958, 2, 1),
#  datetime.date(1958, 3, 1),
#  datetime.date(1958, 4, 1),
#  datetime.date(1958, 5, 1),
#  datetime.date(1958, 6, 1),
#  datetime.date(1958, 7, 1),
#  datetime.date(1958, 8, 1),
#  datetime.date(1958, 9, 1),
#  datetime.date(1958, 10, 1),
#  datetime.date(1958, 11, 1),
#  datetime.date(1958, 12, 1),
#  datetime.date(1959, 1, 1),
#  datetime.date(1959, 2, 1),
#  datetime.date(1959, 3, 1),
#  datetime.date(1959, 4, 1),
#  datetime.date(1959, 5, 1),
#  datetime.date(1959, 6, 1),
#  datetime.date(1959, 7, 1),
#  datetime.date(1959, 8, 1),
#  datetime.date(1959, 9, 1),
#  datetime.date(1959, 10, 1),
#  datetime.date(1959, 11, 1),
#  datetime.date(1959, 12, 1),
#  datetime.date(1960, 1, 1),
#  datetime.date(1960, 2, 1),
#  datetime.date(1960, 3, 1),
#  datetime.date(1960, 4, 1),
#  datetime.date(1960, 5, 1),
#  datetime.date(1960, 6, 1),
#  datetime.date(1960, 7, 1),
#  datetime.date(1960, 8, 1),
#  datetime.date(1960, 9, 1),
#  datetime.date(1960, 10, 1),
#  datetime.date(1960, 11, 1),
#  datetime.date(1960, 12, 1),
#  datetime.date(1961, 1, 1),
#  datetime.date(1961, 2, 1),
#  datetime.date(1961, 3, 1),
#  datetime.date(1961, 4, 1),
#  datetime.date(1961, 5, 1),
#  datetime.date(1961, 6, 1),
#  datetime.date(1961, 7, 1),
#  datetime.date(1961, 8, 1),
#  datetime.date(1961, 9, 1),
#  datetime.date(1961, 10, 1),
#  datetime.date(1961, 11, 1),
#  datetime.date(1961, 12, 1),
#  datetime.date(1962, 1, 1),
#  datetime.date(1962, 2, 1),
#  datetime.date(1962, 3, 1),
#  datetime.date(1962, 4, 1),
#  datetime.date(1962, 5, 1),
#  datetime.date(1962, 6, 1),
#  datetime.date(1962, 7, 1),
#  datetime.date(1962, 8, 1),
#  datetime.date(1962, 9, 1),
#  datetime.date(1962, 10, 1),
#  datetime.date(1962, 11, 1),
#  datetime.date(1962, 12, 1),
#  datetime.date(1963, 1, 1),
#  datetime.date(1963, 2, 1),
#  datetime.date(1963, 3, 1),
#  datetime.date(1963, 4, 1),
#  datetime.date(1963, 5, 1),
#  datetime.date(1963, 6, 1),
#  datetime.date(1963, 7, 1),
#  datetime.date(1963, 8, 1),
#  datetime.date(1963, 9, 1),
#  datetime.date(1963, 10, 1),
#  datetime.date(1963, 11, 1),
#  datetime.date(1963, 12, 1),
#  datetime.date(1964, 1, 1),
#  datetime.date(1964, 2, 1),
#  datetime.date(1964, 3, 1),
#  datetime.date(1964, 4, 1),
#  ...]

# %% [markdown]
# Plot the temperature data for Germany. It is dominated by an oscillation, while the slow rise in temperature is barely visible.

# %%
plt.figure()
plt.plot(dates, temp_ger)
plt.xlabel("Year")
plt.ylabel("Temp [°C]")
plt.title("Temperature per month")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Temperature per month')

# %% [markdown]
# That oscillation is caused by seasonal temperature changes. It's cold in the winter and warm in the summer, even with global warming!
#
# Have a look at the seasonal difference by plotting all years over each other. You have to use the unflattened `temp_arr` and plot each year over the same months.
#
# Hint: If you give pyplot an array with shape $(m, n)$ for the y-axis, it plots $n$ graphs over $m$ datapoints. We want $\#years$ graphs over $\#months$ datapoints. The `temp_arr` array alreay has the correct shape, just select only the overall german temperature! (last element of 2nd axis)

# %%
plt.figure()
plt.plot(months, temp_arr[:,:,-1], c="b", alpha=0.1)
plt.xlabel("Month")
plt.ylabel("Temp [°C]")
plt.title("Monthly temperature over all years")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'Monthly temperature over all years')

# %% [markdown]
# We can look at the Fourier transform of the temperature to identify the seasonal fluctuation.
#
# To plot the spectrum sensibly, we need the correct frequency values. What is the sampling distance `d` of our datapoints if we think in units of years?
#
# Hint: We want the seasonal oscillation to have frequency 1.

# %%
type(temp_ger)
print(temp_ger.shape)
# Out:
# (1668,)

# %%
temp_ger_ft = np.fft.rfft(temp_ger) #Fourier coeffs.
freq = np.fft.rfftfreq(temp_ger.shape[0], d=1/12) #compute frequencies. 
plt.figure()
plt.plot(freq, np.abs(temp_ger_ft))
plt.xlabel("Frequency u [1/year]")
plt.ylabel("|F(u)|")
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, '|F(u)|')

# %% [markdown]
# ## Filtering

# %% [markdown]
# We want to remove the oscillation from our data, so that we can identify the slow rise in temperature over the decades.
#
# First, we apply a Gaussian low-pass filter in Fourier domain. Choose $\sigma$ such that the strong oscillation at $u = 1$ is suppressed. As coordinates, use `freq`.

# %%
sigma = 0.1
w_lowpass = np.exp(-freq**2 / (2*sigma**2)) #frequencies are in fourier space already, hence w is also in Fourier
temp_ger_lowpass_ft = temp_ger_ft * w_lowpass 
temp_ger_lowpass = np.fft.irfft(temp_ger_lowpass_ft).real

# %%
plt.figure()
plt.plot(w_lowpass)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# If we want to preserve other high-frequency features and only want to suppress the seasonal change, we instead apply a bandstop filter to the frequency we want to suppress specifically.
#
# A very crude bandstop filter blocks one frequency completely and lets all others through. You have to select the index where our coordinates `freq` are 1.

# %%
w_bandstop = np.ones_like(freq)
w_bandstop[np.isclose(freq, 1)] = 0
temp_ger_bandstop_ft = temp_ger_ft * w_bandstop
temp_ger_bandstop = np.fft.irfft(temp_ger_bandstop_ft).real

# %%
plt.figure()
plt.plot(w_bandstop)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.figure()
plt.plot(dates, temp_ger, "b", label="Unfiltered")
plt.plot(dates, temp_ger_bandstop, "g", label="Bandstop")
plt.plot(dates, temp_ger_lowpass, "r", label="Lowpass")
plt.xlabel("Frequency u [1/year]")
plt.ylabel("Temp [°C]")
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# Finally, we want to look at the power spectrum of the signal and how it changes from the filters.
#
# Compute the power spectra. The power spectrum $S(w)$ of a signal $f(x)$ is $S(w) = | F (w) |^2$.

# %%
ps_unfiltered = (np.abs(temp_ger_ft))**2
ps_lowpass = (np.abs(temp_ger_lowpass_ft))**2
ps_bandstop = (np.abs(temp_ger_bandstop_ft))**2

# %% [markdown]
# Now we plot the spectra. The unfiltered data shows the large peak at 1, which is suppressed in the bandstopped signal to 0. The lowpass-filtered signal still shows the peak, but it's attenuated together with the other higher frequencies.

# %%
plt.figure()
plt.semilogy(freq, ps_unfiltered, label="Unfiltered")
plt.semilogy(freq, ps_bandstop, label="Bandstop")
plt.semilogy(freq, ps_lowpass, label="Lowpass")
plt.xlabel("Frequency u [1/year]")
plt.ylabel("S(u)")
#plt.xlim(-0.1, 1.2); plt.ylim(1e-3, 1e9)
plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ## Conclusion

# %% [markdown]
# We have removed the seasonal variation from the temperature data and visualized a rise in temperature. For the reasons behind this and what you, as scientists, can do, visit [Public Climate School](https://studentsforfuture.info/public-climate-school/).
